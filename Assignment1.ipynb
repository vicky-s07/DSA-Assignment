# %% [markdown]
# ![WhatsApp Image 2021-05-21 at 2.24.16 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Exercise 1 solutions:

# %% [markdown]
# ![WhatsApp Image 2021-05-21 at 3.45.03 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-05-21 at 3.45.03 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# For Problem Exercise 2,We can say that graph is flucating so There is no upper and lowers bounds so .
#
# Statement 1 and Statement2 both are false

# %% [markdown]
# ![WhatsApp Image 2021-05-21 at 3.16.14 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# For the Question Excersice3 .By looking at the graph the order is
#
# F4>F1>F3>F2

# %% [markdown]
# ![WhatsApp Image 2021-05-21 at 3.20.19 PM.jpeg](data:image/jpeg;base64,...)
